# %% [markdown]
# 아마존 리뷰 데이터에 대한 이해

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
np.random.seed(seed=0)

# %%
# Reviews.csv 파일을 data라는 이름의 데이터프레임에 저장. 단, 10만개의 행(rows)으로 제한.
data = pd.read_csv("Reviews.csv", nrows = 100000)
print('전체 리뷰 개수 :',(len(data)))
# Out:
# 전체 리뷰 개수 : 100000

# %%
data = data[['Text','Summary']]
data.head()
# Out:
#                                                 Text                Summary
# 0  I have bought several of the Vitality canned d...  Good Quality Dog Food
# 1  Product arrived labeled as Jumbo Salted Peanut...      Not as Advertised
# 2  This is a confection that has been around a fe...  "Delight" says it all
# 3  If you are looking for the secret ingredient i...         Cough Medicine
# 4  Great taffy at a great price.  There was a wid...            Great taffy

# %%
# 랜덤으로 10개의 샘플 출력
data.sample(10)
# Out:
#                                                     Text  \
# 3582   I rarely eat anything but whole wheat pasta, b...
# 60498  I absolutely love 5-hour ENERGY! I use it afte...
# 53227  this chocolate is a true treat to eat, perfect...
# 21333  Greenies are very muched loved as a tatsy Trea...
# 3885   I love these noodles.  They are really great f...
# 51521  These are great! As a lover of all chips I'm s...
# 84261  Like other customers I divide these into handf...
# 10685  I recommend this instead for the same price: <...
# 59948  The noodles were all very broken, but the tast...
# 41032  Despite claiming they use the "finest ingredie...
#
#                                             Summary
# 3582                            reminds me of Italy
# 60498               5-hour ENERGY Highly Recommend!
# 53227                             supreme chocolate
# 21333                       Excellent Teeth Cleaner
# 3885                          Great and good price!
# 51521  Delicious, just like Salt and Vinegar Chips!
# 84261                      Great snack, great value
# 10685     It's ok, but certainly not worth the cost
# 59948                          Knorr's beef noodles
# 41032                          HORRIBLE INGREDIENTS

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['Text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['Summary'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 88426
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 72348

# %%
# text 열에서 중복인 내용이 있다면 중복 제거
data.drop_duplicates(subset=['Text'], inplace=True)
print("전체 샘플수 :", len(data))
# Out:
# 전체 샘플수 : 88426

# %%
print(data.isnull().sum())
# Out:
# Text       0
# Summary    1
# dtype: int64

# %%
# Null 값을 가진 샘플 제거
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 88425

# %%
# 전처리 함수 내 사용
contractions = {"'cause": 'because',
 "I'd": 'I would',
 "I'd've": 'I would have',
 "I'll": 'I will',
 "I'll've": 'I will have',
 "I'm": 'I am',
 "I've": 'I have',
 "ain't": 'is not',
 "aren't": 'are not',
 "can't": 'cannot',
 "could've": 'could have',
 "couldn't": 'could not',
 "didn't": 'did not',
 "doesn't": 'does not',
 "don't": 'do not',
 "hadn't": 'had not',
 "hasn't": 'has not',
 "haven't": 'have not',
 "he'd": 'he would',
 "he'll": 'he will',
 "he's": 'he is',
 "here's": 'here is',
 "how'd": 'how did',
 "how'd'y": 'how do you',
 "how'll": 'how will',
 "how's": 'how is',
 "i'd": 'i would',
 "i'd've": 'i would have',
 "i'll": 'i will',
 "i'll've": 'i will have',
 "i'm": 'i am',
 "i've": 'i have',
 "isn't": 'is not',
 "it'd": 'it would',
 "it'd've": 'it would have',
 "it'll": 'it will',
 "it'll've": 'it will have',
 "it's": 'it is',
 "let's": 'let us',
 "ma'am": 'madam',
 "mayn't": 'may not',
 "might've": 'might have',
 "mightn't": 'might not',
 "mightn't've": 'might not have',
 "must've": 'must have',
 "mustn't": 'must not',
 "mustn't've": 'must not have',
 "needn't": 'need not',
 "needn't've": 'need not have',
 "o'clock": 'of the clock',
 "oughtn't": 'ought not',
 "oughtn't've": 'ought not have',
 "sha'n't": 'shall not',
 "shan't": 'shall not',
 "shan't've": 'shall not have',
 "she'd": 'she would',
 "she'd've": 'she would have',
 "she'll": 'she will',
 "she'll've": 'she will have',
 "she's": 'she is',
 "should've": 'should have',
 "shouldn't": 'should not',
 "shouldn't've": 'should not have',
 "so's": 'so as',
 "so've": 'so have',
 "that'd": 'that would',
 "that'd've": 'that would have',
 "that's": 'that is',
 "there'd": 'there would',
 "there'd've": 'there would have',
 "there's": 'there is',
 "they'd": 'they would',
 "they'd've": 'they would have',
 "they'll": 'they will',
 "they'll've": 'they will have',
 "they're": 'they are',
 "they've": 'they have',
 "this's": 'this is',
 "to've": 'to have',
 "wasn't": 'was not',
 "we'd": 'we would',
 "we'd've": 'we would have',
 "we'll": 'we will',
 "we'll've": 'we will have',
 "we're": 'we are',
 "we've": 'we have',
 "weren't": 'were not',
 "what'll": 'what will',
 "what'll've": 'what will have',
 "what're": 'what are',
 "what's": 'what is',
 "what've": 'what have',
 "when's": 'when is',
 "when've": 'when have',
 "where'd": 'where did',
 "where's": 'where is',
 "where've": 'where have',
 "who'll": 'who will',
 "who'll've": 'who will have',
 "who's": 'who is',
 "who've": 'who have',
 "why's": 'why is',
 "why've": 'why have',
 "will've": 'will have',
 "won't": 'will not',
 "won't've": 'will not have',
 "would've": 'would have',
 "wouldn't": 'would not',
 "wouldn't've": 'would not have',
 "y'all": 'you all',
 "y'all'd": 'you all would',
 "y'all'd've": 'you all would have',
 "y'all're": 'you all are',
 "y'all've": 'you all have',
 "you'd": 'you would',
 "you'd've": 'you would have',
 "you'll": 'you will',
 "you'll've": 'you will have',
 "you're": 'you are',
 "you've": 'you have'}

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# NLTK의 불용어
stop_words = set(stopwords.words('english'))
print('불용어 개수 :', len(stop_words))
print(stop_words)
# Out:
# 불용어 개수 : 179
# {'an', 'than', "hadn't", 'is', 'hers', 'was', 'did', 'ma', 'theirs', "you'll", 'more', 'he', 'ain', 'own', 'm', 'so', 'aren', 'or', "wouldn't", 'doesn', 'nor', 'above', 'who', 'up', "isn't", 'before', 're', 'such', "you're", 'won', 'him', 'some', 'whom', 't', 'from', 'when', "weren't", "aren't", 'o', "don't", 'shan', 'too', "couldn't", 'just', 'can', 'couldn', 'while', 'needn', 'them', 'both', 'then', 've', 'against', 'yourselves', 'between', 'am', "you'd", 'if', 'off', 'mightn', 'mustn', "haven't", 'on', 'how', 'will', 'very', 'herself', 'over', 'my', 'its', 'because', 'not', "doesn't", 'hasn', "hasn't", 'most', 'ours', "that'll", 'same', 'further', 'you', 'his', 'why', 'our', 'didn', 'haven', 'itself', 'y', 'for', 'where', 'me', 'what', 'the', 'her', 'had', 'should', 'be', "it's", 'we', 'wouldn', 'to', "shan't", "mustn't", 'doing', 'of', 'your', 'once', 'under', 'no', 'until', 'those', 'other', 'all', 'does', 'as', 'i', 'yours', 'there', 'their', 'a', "won't", 'that', 'do', 'are', 'yourself', 'but', 'isn', 'which', 'wasn', 'hadn', "shouldn't", "she's", 'down', 'during', 'myself', 'here', 'don', 'they', "needn't", 'weren', 'shouldn', 'out', "should've", 'it', 'only', 'being', 'been', 'she', 'this', "wasn't", 'any', "you've", 'each', 'and', "mightn't", 'these', 'again', 'through', 'with', 'having', "didn't", 'now', 'at', 'by', 'were', 'has', 'into', 'll', 'himself', 'ourselves', 'few', 'd', 'after', 'about', 'themselves', 'in', 'have', 'below', 's'}

# %%
# 전처리 함수
def preprocess_sentence(sentence, remove_stopwords = True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열  제거 Ex) my husband (and myself) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","",sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah

    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stop_words if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'
print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, 0))
# Out:
# everything bought great infact ordered twice third ordered wasfor mother father
# great way to start the day

# %%
# Text 열 전처리
clean_text = []
for s in data['Text']:
    clean_text.append(preprocess_sentence(s))
clean_text[:5]
# Out:
# <ipython-input-62-486d11b728f3>:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
# Summary 열 전처리
clean_summary = []
for s in data['Summary']:
    clean_summary.append(preprocess_sentence(s, 0))
clean_summary[:5]
# Out:
# <ipython-input-62-486d11b728f3>:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# <ipython-input-62-486d11b728f3>:4: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy']

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary

# %%
# 길이가 공백인 샘플은 NULL 값으로 변환
data.replace('', np.nan, inplace=True)
print(data.isnull().sum())
# Out:
# Text        0
# Summary    70
# dtype: int64

# %%
data.dropna(axis = 0, inplace = True)
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 88355

# %%
# 길이 분포 출력
text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('Summary')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 2
# 텍스트의 최대 길이 : 1235
# 텍스트의 평균 길이 : 38.792428272310566
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 28
# 요약의 평균 길이 : 4.010729443721352

# %%
text_max_len = 50
summary_max_len = 8

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.7745119121724859

# %%
below_threshold_len(summary_max_len, data['Summary'])
# Out:
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9424593967517402

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 65818

# %%
data.head()
# Out:
#                                                 Text                Summary
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1      sostoken not as advertised      not as advertised eostoken
# 2    sostoken delight says it all    delight says it all eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %%
encoder_input = np.array(data['Text'])
decoder_input = np.array(data['decoder_input'])
decoder_target = np.array(data['decoder_target'])

# %%
#데이터 분리
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [61165 60938 37145 ... 45440 26023  1298]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :',n_of_val)
# Out:
# 테스트 데이터의 수 : 13163

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 52655
# 훈련 레이블의 개수 : 52655
# 테스트 데이터의 개수 : 13163
# 테스트 레이블의 개수 : 13163

# %%
#정수 인코딩
src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(encoder_input_train)

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 31809
# 등장 빈도가 6번 이하인 희귀 단어의 수: 23569
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 8240
# 단어 집합에서 희귀 단어의 비율: 74.0953818101795
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.3524845525543077

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words = src_vocab)
src_tokenizer.fit_on_texts(encoder_input_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train)
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# %%
print(encoder_input_train[:3])
# Out:
# [[34, 203, 5868, 503, 32, 19, 131, 37, 2, 86, 5, 477, 1, 2997, 1191, 414, 417, 25, 4375, 1686, 6140, 5, 25], [5, 158, 2092, 4076, 1370, 809, 809, 173, 104, 998, 2998, 127, 3202, 1116, 2544, 5, 4076], [6785, 205, 222, 1574, 2802, 309, 246, 457, 725, 2684, 2437, 1117, 42, 725, 5435, 1477, 464, 377, 114, 43, 301, 96, 2412, 2545, 6449, 96, 953, 1815, 4508]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 10377
# 등장 빈도가 5번 이하인 희귀 단어의 수: 7992
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2385
# 단어 집합에서 희귀 단어의 비율: 77.01647875108412
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.809679351549808

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words = tar_vocab)
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train)
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# %%
print(decoder_input_train[:5])
# Out:
# [[1, 4, 66, 24, 35], [1, 6, 49, 454], [1, 459, 565, 12, 80], [1, 1464, 1019], [1, 3, 1020]]

# %%
print(decoder_target_train[:5])
# Out:
# [[4, 66, 24, 35, 2], [6, 49, 454, 2], [459, 565, 12, 80, 2], [1464, 1019, 2], [3, 1020, 2]]

# %%
#빈 샘플 제거
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

# %%
print('삭제할 훈련 데이터의 개수 :',len(drop_train))
print('삭제할 테스트 데이터의 개수 :',len(drop_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 1235
# 삭제할 테스트 데이터의 개수 : 362

# %%
encoder_input_train = np.delete(encoder_input_train, drop_train, axis=0)
decoder_input_train = np.delete(decoder_input_train, drop_train, axis=0)
decoder_target_train = np.delete(decoder_target_train, drop_train, axis=0)

encoder_input_test = np.delete(encoder_input_test, drop_test, axis=0)
decoder_input_test = np.delete(decoder_input_test, drop_test, axis=0)
decoder_target_test = np.delete(decoder_target_test, drop_test, axis=0)

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 51420
# 훈련 레이블의 개수 : 51420
# 테스트 데이터의 개수 : 12801
# 테스트 레이블의 개수 : 12801
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:5071: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asarray(arr)

# %%
#패딩
encoder_input_train = pad_sequences(encoder_input_train, maxlen = text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen = text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen = summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen = summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen = summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen = summary_max_len, padding='post')

# %%
#seq2seq + attention으로 요약 모델 설계 및 훈련
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 50)]                 0         []
#
#  embedding (Embedding)       (None, 50, 128)              1024000   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 50, 256),            394240    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 50, 256),            525312    ['lstm[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  embedding_1 (Embedding)     (None, None, 128)            256000    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 50, 256),            525312    ['lstm_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_3 (LSTM)               [(None, None, 256),          394240    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm_2[0][1]',
#                               (None, 256)]                           'lstm_2[0][2]']
#
#  dense (Dense)               (None, None, 2000)           514000    ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 3633104 (13.86 MB)
# Trainable params: 3633104 (13.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/ukairia777/tensorflow-nlp-tutorial/main/20.%20Text%20Summarization%20with%20Attention/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 50)]                 0         []
#
#  embedding (Embedding)       (None, 50, 128)              1024000   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 50, 256),            394240    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 50, 256),            525312    ['lstm[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  embedding_1 (Embedding)     (None, None, 128)            256000    ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 50, 256),            525312    ['lstm_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_3 (LSTM)               [(None, None, 256),          394240    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm_2[0][1]',
#                               (None, 256)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  ((None, None, 256),          131328    ['lstm_2[0][0]',
#  Layer)                       (None, None, 50))                      'lstm_3[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 512)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  dense_1 (Dense)             (None, None, 2000)           1026000   ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 4276432 (16.31 MB)
# Trainable params: 4276432 (16.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)
history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
          validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
          batch_size = 256, callbacks=[es], epochs = 1)
# Out:
# 201/201 [==============================] - 1180s 6s/step - loss: 2.5156 - val_loss: 2.4264

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
#seq2seq + attention으로 요약 모델 테스트
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# %%
# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat)

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    sentence=''
    for i in input_seq:
        if(i!=0):
            sentence = sentence + src_index_to_word[i]+' '
    return sentence

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    sentence=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            sentence = sentence + tar_index_to_word[i] + ' '
    return sentence

# %%
for i in range(500, 1000):
    print("원문 : ",seq2text(encoder_input_test[i]))
    print("실제 요약문 :",seq2summary(decoder_input_test[i]))
    print("예측 요약문 :",decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 :  user tea last five years even compared several brands keeps coming winner truly great product makes best brew honest tea lover
# 실제 요약문 : great tea
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 0s 43ms/step
# 예측 요약문 :  great
#
#
# 원문 :  entire family enjoys loose leaf tea favorite picky tea good quality flavor mellow even though earl grey bitter like teas smooth highly recommend trying repeat customer
# 실제 요약문 : fantastic quality and taste
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 예측 요약문 :  great
#
#
# 원문 :  purchased tea year ago thought great ran reordering decided read product reviews reviews mentioned whole leaf tea decided look whole leaf variety really tell difference dilmah bit bitterness bergamot flavors strong look whole leaf variety instead
# 실제 요약문 : good but not great
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 58ms/step
# 예측 요약문 :  great
#
#
# 원문 :  absolutely best earl grey ever lot smooth rich enough bergamot others said tea never bitter full bodied plan never buying brand love grown single origin comes loose leaf bought green tea loved well cheers
# 실제 요약문 : no
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 예측 요약문 :  great
#
#
# 원문 :  right combination aroma kick taste rich bitter tried numerous loose leaf teas one best far
# 실제 요약문 : very good tea
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  purchased based reviews dissapointed finished bulk order bigelow earl grey amazon really good thought oh tea good reviews ought better save money go bigelow kidding
# 실제 요약문 : blech
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약문 :  great
#
#
# 원문 :  item received plastic containers inches tall filled peanut butter cups hersheys kisses godiva chocolates wooden fence rabbit missing ripoff
# 실제 요약문 : item received is completely different than item description
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  sent baskets two grandkids get worthless piece junk could bought dollar store less dollar warned buy least false advertising want give one star could review unless answered question could rate minus stars would although probably even rate
# 실제 요약문 : very disappointed with amazon
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  year old cat seemingly developed stomach issues vomiting nearly every day intolerance dyes unnecessary stuff put mass market cat foods since gotten sick cat sensitive belly try also say really likes food try others along way love food smells fresh tiny little balls smaller pea easy eat digest
# 실제 요약문 : no more
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  halo dry cat food feed cat coat ever seen even vet mentioned never seen cat shiny coat
# 실제 요약문 : great for
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cat eating food year loves highly recommend
# 실제 요약문 : awesome
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  year old cat tried couple organic cat foods liked every one really likes halo spot stew read spots stew veterinarian sunday paper others said wonderful things bought thru amazon tiger loves tiger highly recommends
# 실제 요약문 : says spot winner
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  first bag three cats gobbled however oldest cat started losing fur turned nose second bag think anything wrong food two still happy getting older still enough easily transition went back completely food
# 실제 요약문 : better at first
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  purchased food health cat food recalled got seafood sensitive stomachs cat throws eats sometimes loves flavor problems getting eat knew flavor would good choice cat goes nuts tuna fish make sure shop around find sale sold locally around must buy online love preservatives made food grade meats canada ingredients
# 실제 요약문 : my cat loves this food
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약문 :  great
#
#
# 원문 :  needed find cat food cats healthy also tasted good alot cat food grocery meet criteria pleased halo cats love
# 실제 요약문 : cat food
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cat sensitive tummy since halo sensitive stomachs bathroom issues everything normal smelly box course checked vet first
# 실제 요약문 : great for sensitive
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cat rash making worse constant scratching changed kitty food within two weeks rash gone ate seen rash since healthiest recommend without reservation
# 실제 요약문 : healthy kitty
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  since started using halo cat food five indoor cats stomach disappeared oh cat love food
# 실제 요약문 : no more stomach problems
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  trying many expensive good cat cat food really hoping one one cat weight low carb food excited try neither three cats eat bought two flavors turkey seafood flavor eat either one stuck another two bags cat food
# 실제 요약문 : cat will not eat this
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  significantly swedish like good dark roast coffee make wish berries go french press owners even nice enough sign receipt wish well thank mark
# 실제 요약문 : amazing coffee quick shipping
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  good plenty really anything else say still old fat free delicious licorice candy always one thing note amount candy getting getting lot seriously getting fairly large bags candy definitely last awhile
# 실제 요약문 : good just like you remember it
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  one favorite candies time sugar coated black licorice candy comes white purple eating good plenty movie theater since forever got tons trick treating years eat much might get sugar high headache highly recommend candy
# 실제 요약문 : good rules
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  must gotten used rather stale good plenty received order tasted first bag pleasantly surprised find soft licorice yum packaging problems order packages movement inflated baggie things yes
# 실제 요약문 : what difference freshness makes
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약문 :  great
#
#
# 원문 :  really like bags good plenty right size eating sharing get usual theater box size enough share put away later one nice thing good plenty keep person regular like black licorice love colorful sugar coating adds enough sweetness cut licorice bite bags travel well easy theater enjoy
# 실제 요약문 : love good
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  always always great candy loved young adore grown
# 실제 요약문 : loves good
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  boxed candy hard time granted pay bit bagged candy soft chewy meant worth understand good plenty company sell bagged candy stores thank amazon
# 실제 요약문 : soft
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약문 :  great
#
#
# 원문 :  good one favorite candies since early recently someone told remembered black white rather pink white told mistaken anyone remember pink white
# 실제 요약문 : different color
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  know want fresh well packaged shipping
# 실제 요약문 : buy these
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  one packet puncture hole one packet cut plenty licorice candies ounce packets
# 실제 요약문 : packet
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  packages came holes candy spilled love good plenty must type packaging problems hopefully receive refund problem fixed next subscribe save shipment arrives problem remaining candy fresh tastes great
# 실제 요약문 : love the candy hate the packaging problem
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  high quality marzipan loaves perfect size much little great price sold individually farms highly recommend prepared eat one cannot stop
# 실제 요약문 : very very good
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  fresh marzipan world bars arrived stale dry much flavor maybe take chance got marzipan way get
# 실제 요약문 : stale
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  previously bought marzipan potatoes sold tried marzipan best ever tasted chocolate overpowering potatoes better pure marzipan flavor really comes
# 실제 요약문 : okay but disappointing
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  one finest finest brand marzipan wonderful almond taste sweet dark chocolate terrific bars shipped quite fresh delicious tried ought
# 실제 요약문 : best marzipan
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약문 :  great
#
#
# 원문 :  good soda bread easy make also obtained one item gift
# 실제 요약문 : good product
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약문 :  great
#
#
# 원문 :  always quality product good ingredients keeps blood sugar good level good traveling taking go melt
# 실제 요약문 : great
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  looking soft chew product replace skin coat additive used buy another manufacturer dog like gel tabs pet supply stores sell pet naturals product great tasting actually looks first bowl eating food since learned local pet store sells items choose buy product locally cost given shipping handling charges line vendor
# 실제 요약문 : great product my pup
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  needed size larger bonsai right plus like look pot
# 실제 요약문 : just right
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 예측 요약문 :  great
#
#
# 원문 :  use fork easy biggest problem mix usually beating especially recipe calls adding eggs cooks tend beat blend point eggs become frothy make big difference outcome beat eggs wet ingredients first lightly add mix half cup time stir beat wet see huge difference outcome
# 실제 요약문 : cannot beat
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love products exception delicious easy great dessert use church meetings always gone
# 실제 요약문 : yummy and easy pecan bars
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  impressed made friend adores pecan pie liked pie add little butter crust turned delicious making
# 실제 요약문 : wow these taste better than pecan pie
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  wonderfully easy preparation bars incredibly good cannot stop eating cannot miss mix
# 실제 요약문 : yummy
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  product tasted good enjoyed would order love red velvet cake knew would like red velvet
# 실제 요약문 : great
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  first time trying must say lived expected like want try think go wrong swiss colony brand whole cake fresh good taste
# 실제 요약문 : tasty
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약문 :  great
#
#
# 원문 :  stuff great second pack purchased gold dash flax seems less noticeable regular added food recipes put ground flax son peanut butter jelly sandwiches boys even notice use gold dash flax also use pancake batter muffins waffles etc
# 실제 요약문 : wonderful healthy
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great product good price fast shipping product stores much higher price lucky enough find great deal would highly recommend seller
# 실제 요약문 : flax
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  really like anything peppermint decided give one shot main thing like really wish minty flavorful looking plain ish salt water taffy could give try looking something minty one
# 실제 요약문 : it is okay
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  got formula time well packaged knew damaged shipment
# 실제 요약문 : great product for the money
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  found add little bit splenda vanilla maple extract make mixer taste like regular pina next best flavor make would lemon mixer rest mixes bit tough
# 실제 요약문 : best of the low carb
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love pina coladas able drink years fattening tried bob mix find bad bit different taste nothing offensive used coconut rum
# 실제 요약문 : not bad
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  makes wonderful pina coladas cannot lot sugar drinks weekend cannot wait
# 실제 요약문 : great
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  drink disaster taste bb pina colada mix bad thought expired using splenda bad idea bob read reviews recipe gotta go sugarless try stevia much smoother
# 실제 요약문 : worst drink mix ever
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  high hopes product like splenda normally drink diet soda anyway feel like used taste non diet soda drinkers complain unfortunately awful first sip rd could take funky taste anymore throw may still try another flavor hope different result definitely recommend pina colada mix
# 실제 요약문 : terrible after taste
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  margarita mix excellent also cranberry martini mix pretty good really disappointing coconut taste aftertaste feels like something coating mouth drink bought bottle package toss
# 실제 요약문 : not very good
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  martini stuffed olive olives rich flavor bland salty flavor green olives really taste red choose gin care less olive temptation snack olives else martini
# 실제 요약문 : no other martini olive will do
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  bought olives small market spain come course less expensive best olives ever worth price
# 실제 요약문 : best olives ever
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  peanuts arrived timely manner along rest soon looked realized heated along journey colors onto one another even sticking wanted use decorate cupcakes sticking bleeding make hard use purpose sure taste fine disappointed way handled shipping
# 실제 요약문 : over
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  huge hit daughter rd birthday party theme downside ordered smaller amount guests
# 실제 요약문 : birthday party
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mild delicious us love extra kick sauce great flavor spicy sauce versatile try using pizza salad dressing marinade meats veggies
# 실제 요약문 : good
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  got almonds daughters wedding candy buffet look beautiful picture taste good pricey worth mixed color almonds looks careful almonds order theres sold cheaper careful also theres gold wrapping ones gold finish shiny coat ones looking beautiful gold almonds thank
# 실제 요약문 : beautiful
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  husband tried several brands granola topping morning yogurt back nature cranberry pecan best far local markets stopped stocking went online find sources six ten bags time one product needs perfect balance crunch chewiness flavor small breakfast filling satisfying enough entire morning
# 실제 요약문 : back to nature granola
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  one favorite time granola chewy crunchy sweet great flavors think supply must dried two getting stopped offering pain
# 실제 요약문 : really really tasty
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cereal mixed adds another level morning healthy breakfast get soggy milk important
# 실제 요약문 : excellent granola
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  absolutely love back nature cranberry pecan granola awesome mixed yogurt complete meal deal amazon much better local grocery store price
# 실제 요약문 : wonderful
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  granolas back nature cranberry pecan one best ones
# 실제 요약문 : yummy
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  turned granola sister lives another state returned home difficulty finding area thank goodness amazon order time share sister use make yogurt fresh strawberries blueberries vanilla yogurt makes perfect breakfast snack plus pretty healthy filling
# 실제 요약문 : the best granola
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  seems great product much appreciated daughters apparently box adorable send fresh product sellers rely overnight shipping shipped packages night holiday despite big storm package got fine package days late sellers pretty though tried fair still give stars future wish would ask day person would like package go
# 실제 요약문 : watch out for shipping
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  first tried item year ago saw local stop shop supermarket creek organic apple sauce golden ounce count cups since digestive cannot use regular applesauce resorted using organic foods like creek organic brand much absolutely delicious would use brand
# 실제 요약문 : organic review
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약문 :  great
#
#
# 원문 :  daughter enjoys cinnamon apple sauce one delivers tastes much better store brands loaded high fructose corn syrup try hard eat organic products much possible highly recommend product lunches snacks
# 실제 요약문 : tasty goodness
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  salt free lemon pepper taste great anything mrs dash seasonings best salt free products enhance anything use salt free lemon pepper favorite using long market
# 실제 요약문 : salt free
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love mrs dash spices altogether love one fish chicken spice salad dressing homemade commercial always put seasonings two hours cooking possible steam lot also great spinach apple cider vinegar seasoning bits vegetable make lovely surprise flavor eat best price found amazon
# 실제 요약문 : yum
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약문 :  great
#
#
# 원문 :  dog food wonderful golden allergic lot products well received order quickly happy
# 실제 요약문 : dog food
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mix three spoons picky dry food every morning evening actually eats entire bowl hard get dog eat feed dry version food dog loves needs wet recommend product anyone picky dog need ton spoons wa la dog eat
# 실제 요약문 : dogs love the taste
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  whole department addicted wonderful little treats candy jar empty end week much better option rather small bags getting local pharmacy store individually wrapped pieces make treat everyone grab
# 실제 요약문 : office addiction
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great pass everyone smiles get one easy stash rainy day purse office
# 실제 요약문 : office treats
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  best grain hot cereal blend eaten years better bob red mill stone brands easy cook stove top microwave cream west really shines soak overnight water turn stove morning use make homemade grain bread delicious
# 실제 요약문 : superb grains make the best cereal
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  grain really good store apple valley stopped carrying brand going order online think would really like something order online far food goes lol good stuff
# 실제 요약문 : excellent taste
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mother used noodles growing moved half nation away tried find noodle never could find one noodles sold many stores finding order awesome
# 실제 요약문 : best egg noodles ever
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  best noodles buy taste like homemade ones mom used make noodle comes close tasting homemade glad amazon sells hard find stores
# 실제 요약문 : best noodles you can buy
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  grandmother used make homemade noodles rolling dough rolling pin using knife cut noodles long strips never thought would able find anything close homemade noodles mrs noodles sure come close sure cook noodles become soft mushy thank mrs bringing back memories grandma kitchen
# 실제 요약문 : yummy noodles
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mrs noodles best ever used chicken soup highly recommend cook wants make difference consistency noodles soup casserole
# 실제 요약문 : best noodles ever
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  noodle taste like homemade ones grandma made local store quit ordering order online
# 실제 요약문 : just like homemade
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  noodles cook thick chewy instead turning never leftover noodle place serve local supermarket stopped carrying delighted find available good pot roast gravy also good oriental dishes buy frozen easy eat also make great soups
# 실제 요약문 : these are like homemade noodles
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mrs noodles around since child sell local stores easy find amazon com promptly ordered could split order mom noodle used many polish dishes nice pantry especially arrived matter days ordered
# 실제 요약문 : yum
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  product like expected long time cook normal chinese noodle
# 실제 요약문 : the noodle is not good for me
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  excellent salsa nice chunky good flavor spice detectable spice overwhelming
# 실제 요약문 : yum
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  saw advertised tv found one grocery glad see get amazon use marinades stir frying time think might add nice twist regular soy sure stores around jumped board
# 실제 요약문 : this is terrific stuff
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  really sour product highly recommend product sour candy lovers
# 실제 요약문 : sour
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  hard time finding stuff love glad could find shipping little pricey
# 실제 요약문 : favorite candy
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약문 :  great
#
#
# 원문 :  favorite sour candy ever great company mailed regarding nutritional info recieved reply within hours buy future
# 실제 요약문 : yay
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  would say marzipan germany trend best quality marzipan candy two companies match quality one germany famous making marzipan makers certainly bad good three look forward day amazon com offer standard chocolate covered marzipan bars sale cost somewhat less well
# 실제 요약문 : the best quality marzipan
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  awesome noodles would recommend rinsing noodles thoroughly cook noticed odd flavor prepared without rinsed
# 실제 요약문 : yum
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love simply organic great item sprinkle meal salad highly recommend bottles really packed room settling get worth
# 실제 요약문 : great
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great year old loves great breakfast great healthy snack ready minutes made kitchen smell like fresh baked banana bread cant wait try flavors
# 실제 요약문 : love banana
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  favorite smoothies really great yogurt flavor subtle peach flavor overpowering like white peach absolutely delicious
# 실제 요약문 : great not overly
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  yr old month old mt dog think best treat
# 실제 요약문 : the girls love them
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  happy see natural dry cat food walmart fed three cats food months like diarrhea problems checked fda recall list closest search match fda site nutro natural product
# 실제 요약문 : my cats all eat it
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  husband got new grill past spring grilling trying everything anything favorite seasoning chicken fish love steak prefer city steak seasoning unbeatable poultry fish
# 실제 요약문 : great great great
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  using crust rubs years best dry rubs market
# 실제 요약문 : the best dry on the market
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  rub great salmon easy use lots different herbs try chicken next
# 실제 요약문 : rub
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great coffee low caffeine content decided try expecting cut back caffeine love continue use favorite
# 실제 요약문 : great coffee
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약문 :  great
#
#
# 원문 :  flavor coffee okay felt labeled french roast deep roasted flavor love much french roast much mild bland roast
# 실제 요약문 : should not be french roast
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  absolutely without doubt best dressing ever eaten salad get dressing mouth think could drink right bottle needs salad
# 실제 요약문 : the best
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 예측 요약문 :  great
#
#
# 원문 :  dressing nutty tangy time nice creamy feel palate could use product everything girlfriend girlfriend enjoy
# 실제 요약문 : miso
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  feel cranberry juice little sour cherry flavor might choice lot cherry flavor juice good indeed
# 실제 요약문 : yummy
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약문 :  great
#
#
# 원문 :  looked everywhere pasta ordered excellent certain pasta dishes used olive garden many dishes love love love
# 실제 요약문 : excellent product
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  using chocolate number years always get big compliments results tons better grocery store chocolate name brands like godiva ghirardelli like white chocolate best started shopping lot comparison shopping price best bought many things never complaint quality service
# 실제 요약문 : great chocolate great seller
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  difficult time finding locally glad find available order online dog loves keep entertained busy chewing fast shipping thanks ordering
# 실제 요약문 : says they are good
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  better going costco buy amazon frequently stock good buy
# 실제 요약문 : when they have these they are great buy
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  favorite lifesaver like buying large bag lifesavers percent bigger stash everywhere work home car great freshening breath something suck
# 실제 요약문 : yummy mints
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  almost dying grocery store sold pumpkin seed mostly salt seed energy club seeds outstanding easily eat tasty handfuls without water standing enjoy
# 실제 요약문 : pumpkin seed the better
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  good taste good crunch salty shells fairly thin would like see bigger bags lower price
# 실제 요약문 : very tasty snack
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  awesome taste perfect crunch best seeds ever mention love nearly salty seeds
# 실제 요약문 : awesome
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  least like sensitive stomachs may regret shells little rough digest always limit many eat one sitting addictive
# 실제 요약문 : eat the
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  pumpkin seeds yummy first thought small wrong perfect size come oz bags makes perfect taking car kids loved overly salted lightly best part crispy soft bland like shelf somewhere ages perfect buy
# 실제 요약문 : crispy yummy perfect size
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  seeds perfect amount salt crispiness truly taste like pumpkin seeds would bake huge step compared typical bleached salty seeds others sell definitely recommend brand
# 실제 요약문 : to homemade as you can get
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  one things hate buying snack food companies get right amount salt foods problem great flavor nice sized packets
# 실제 요약문 : perfect
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love pumpkin seeds bag resealable take small handful keep rest fresh really crispy taste amazing try
# 실제 요약문 : nice and crispy
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 예측 요약문 :  great
#
#
# 원문 :  fantastic bought two cases salty enough able eat many like without getting overly salty likely buy run crispy seeds hard find grocery stores found like convenience gas station cannot remember checked
# 실제 요약문 : fantastic crispy seeds
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  energy club crispy pumpkin seeds ounce bags favorite pumpkin seeds snack lightly salted crunchy good flavor
# 실제 요약문 : energy club crispy pumpkin seeds ounce bags
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  difficult finding pumpkin seeds area turned amazon usually eat david pumpkin seeds searching amazon came across reviews seemed decent enough decided give try disappointed seeds crispy lightly salted perfect snack like taking seeds shell product like eating whole try
# 실제 요약문 : just right
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  best like kind seeds make halloween like white ones find gas station stores like taste fresh oven brown lightly salted far best ever
# 실제 요약문 : just like you made them yourself
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  seed taste really good wish little bigger would given rather enjoy
# 실제 요약문 : great tasting pumpkin seeds
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love dried fruit apricots best ever moist best quality
# 실제 요약문 : just perfect
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  nice smooth coffee part keurig cup extra bold sure case nice smooth albeit rather mild flavor however cups harsh almost acidic quality particularly pleasant produces nice cup coffee
# 실제 요약문 : solid addition to the cup
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  order pearl sugar make waffle looked belgian pearl sugar way big sugar right size amount waffle definitely order later need
# 실제 요약문 : like this product
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cannot imagine could mess sugar product exactly supposed tried recipe box little dry dense first thing baked years could
# 실제 요약문 : it is pearl sugar
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  used waffle recipe said would dissolve make air pockets sweetness resulting light crispy waffle dissolve became burned clusters got stuck waffle iron waffles like lead sickening sweet basically worst ones ever eaten certainly would recommend pearl sugar anyone
# 실제 요약문 : disappointed
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  well says add anything tiny bit works wonders fast delivery family run farm store average pricing
# 실제 요약문 : product for gluten free baking
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  happy find price sure good product unfortunate part seem charge shipping according price item weight time add shipping price xanthan gum pay anywhere savings
# 실제 요약문 : good price questionable shipping
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  dont know anyone complain product pricey walk store prepared pay size xanthan gum also barry farms best selection every food product gluten free good prices happy ordered previously little bag xanthan gum lasted year bake alot
# 실제 요약문 : best deal
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  xanthan gum works great agent cooking hot meals even smoothies blender takes place corn starch flour making stew tried buying product health food stores could find amazon tiny bit goes long way even though bag small last long time
# 실제 요약문 : essential in low carb cooking
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  used product make works wonders sure else used makes great
# 실제 요약문 : like it
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  celiac disease make foods scratch product difficult find average store super fast shipping never run
# 실제 요약문 : baking
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  shipped quickly good condition exactly wanted needed gluten free lifestyle thanks
# 실제 요약문 : very pleased
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# ...
# 실제 요약문 : not good
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  perhaps snacks ten years old tried failed find expiration date fruit snacks firm almost crispy outer surface much flavor boot bought brand strawberry fruit snacks pretty good would steer toward flavor another product entirely
# 실제 요약문 : taste like they are years old
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  good price chex snacks quick delivery arrived good condition order quite pleased amazon grocery purchases made last months
# 실제 요약문 : good price
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 예측 요약문 :  great
#
#
# 원문 :  tastiest snack ever eaten low calories little pretzels small cheese crackers chex mix little crackers delicious
# 실제 요약문 : calorie snack mix cheddar
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cannot find grocery store please keep amazon great snack love
# 실제 요약문 : love them
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  cold find local stores one favorite snacks calories per pack excellent price
# 실제 요약문 : calorie snack
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  chocolate mousse delicious directions simple easy follow truly restaurant quality mousse would proud serve anyone also versatile used pastry filling even made little frozen mousse pops love
# 실제 요약문 : delicious and easy
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mousse good giving everyone christmas list mousse die everyone ever served licks glass clean easy make lives claims
# 실제 요약문 : sweet
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  delicious super easy made guests thought genius definitely worth trying
# 실제 요약문 : mm
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약문 :  great
#
#
# 원문 :  recently ordered several varieties flavored stevia liked part orange little bitter used drinks works sweeten taste much orange use enough taste orange drink bitter much sweetening great concept though
# 실제 요약문 : sweet but not very
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 예측 요약문 :  great
#
#
# 원문 :  happy product tried almost flavors orange favorite feel versatile flavors available using year enjoy daily basis water bottle also add tea iced hot little goes long way sweet light refreshing highly recommended
# 실제 요약문 : favorite flavor
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 예측 요약문 :  great
#
#
# 원문 :  sweetleaf liquid stevia orange great sweetener tea hot iced use one drop per ounce beverage bottle lasts long takes drink tea box tea bags product purchasing health food store buying pack subscription item amazon clear orange ounces wonderful bargain free shipping
# 실제 요약문 : liquid stevia orange
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great product lasts long time ideal hcg diet tastes wonderful really good sliced lemons
# 실제 요약문 : quality product
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 57ms/step
# 예측 요약문 :  great
#
#
# 원문 :  orange pleasant orange aroma appeal ends takes quite drops noticeable level taste ends bitter product live positive hype buying one
# 실제 요약문 : it has an orange scent but
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 예측 요약문 :  great
#
#
# 원문 :  use sodastream make flavored seltzer water tastes much better sodastream brand tried vanilla orange root beer great amazon price especially subscription much cheaper sprouts recall cost almost double cost amazon
# 실제 요약문 : good taste
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  expected citrus flavor know taste good green tea
# 실제 요약문 : fine but not too citrus flavored
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약문 :  great
#
#
# 원문 :  plain water great orange taste drinking add drops enjoy taken place drinking soda good thing
# 실제 요약문 : wow great taste
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  tried several flavors sweetleaf products problems ones recently received seem watered used able sweeten one liter bottle seltzer two full stuff two barely taste friend noticed issue berry flavor purchased
# 실제 요약문 : disappointed with strength
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  occasionally like add little flavor club soda mineral water gives healthy choice sweet really restrict carb intake takes couple drops oz bottle water satisfy
# 실제 요약문 : good addition to healthy diet
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great tasting sweetener compared sugar calories give us stomach aches like artificial sweeteners often sodastream managed kick day coke habit coke something tasty fizzy drink liters day subscription two bottles month use new one comes
# 실제 요약문 : great tasting sweetener
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  daughter loves orange water sugar family looking way kids could still little sweetness life besides fruit trick super shipper saver even though prime comes automatically never run good price originally bought store double price
# 실제 요약문 : makes great water for kids
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  got add water help son drink hates dont like either leaves funny taste
# 실제 요약문 : son hates it
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약문 :  great
#
#
# 원문 :  stevia orange great put drops water bottle hate drink water really taste therefore drink water like lemon stevia drops also
# 실제 요약문 : stevia
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love orange flavor tea smoothies mixed fresh lemon water sweetleaf one best tasting shipping fast wrapped securely
# 실제 요약문 : very good
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  trying get away sugar substitutes love flavors tea coffee stevia flavors wonderful
# 실제 요약문 : this is great
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  using stevia sweetener years always used kal white powder stevia like taste best found sweetleaf stevia first tried hazelnut flavor gave try chocolate raspberry orange flavor love love orange flavor coffee oatmeal greek yogurt gives gentle touch orange definitely taste
# 실제 요약문 : delicious
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 예측 요약문 :  great
#
#
# 원문 :  okay citrus flavor expected tastes fake sweet leaf flavors excellent one merely average
# 실제 요약문 : not crazy about it
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  excellent every way amazon price better find store love use pasta product fast cooks perfection kraft excellent job people love enjoy
# 실제 요약문 : very very good
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 예측 요약문 :  great
#
#
# 원문 :  best macaroni cheese ever thank goodness amazon find grocery stores live bacon adds little something extra set aside regular macaroni cheese
# 실제 요약문 : delicious
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  got creamy cheesy flavor original added smokiness bacon quick easy delicious
# 실제 요약문 : yum
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약문 :  great
#
#
# 원문 :  something completely wrong way bacon bits packaged shells cheese taste additionally cheese sauce taste regular shells cheese sauce good way stick original
# 실제 요약문 : the bacon bits
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 예측 요약문 :  great
#
#
# 원문 :  salt salt lovers dream come true amazing everything tried reccommend salt every home taste buds
# 실제 요약문 : the best of the best in salt
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  come recommended amounts use sweeten foods look online thought tasted ok husband brother thought left bitter aftertaste notice taste neither sister law
# 실제 요약문 : ok product
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love mustard first received gift got hooked put everything makes better gift traditional bottle wine going someone house dinner discovered hard find stores easy find amazon first came brought france
# 실제 요약문 : great gift
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 예측 요약문 :  great
#
#
# 원문 :  favorite gourmet mustard perfect recipe addition condiment buy gift time
# 실제 요약문 : my favorite gourmet mustard
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  mints whiff local candy decided get anyway since latte mints tried like one direction
# 실제 요약문 : tastes great but smells
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 예측 요약문 :  great
#
#
# 원문 :  great pack kids lunch great way sit eat whole pack wish cheaper though
# 실제 요약문 : love
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 예측 요약문 :  great
#
#
# 원문 :  tea favorite tea distinct flavor smoked dried bags tea say make cups tea tea strong flavor used tiny bit tea leaves per cup managed get cup one bag used far overall im satisfied purchase
# 실제 요약문 : good loose leaf tea
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 예측 요약문 :  great
#
#
# 원문 :  family england love tea given tea gift skeptical first fell love soon tasted truly perfect tea love hot tea sun tea
# 실제 요약문 : an excellent authentic english tea
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great
#
#
# 원문 :  received tea house warming basket wonderful could drink day glad find amazon think next time go straight save couple bucks worth
# 실제 요약문 : the most wonderful tea
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 예측 요약문 :  great
#
#
# 원문 :  blend tea remember drinking tea drinker years got pack gift basket christmas son wife ordering even noon christmas day remember drink hope merry christmas
# 실제 요약문 : christmas gift got me hooked
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 예측 요약문 :  great
#
#
# 원문 :  best tea ever smooth delicious highly recommend
# 실제 요약문 : english tea no
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 예측 요약문 :  great
#
#
# 원문 :  love tea full bodied flavor aroma smooth relaxing order two packs one hundred shipping much less
# 실제 요약문 : the best tea
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 51ms/step
# 예측 요약문 :  great
#
#
# 원문 :  buying tea another store already knew good fact think best tea one get kind hooked even awake first cup morning anyway convenient packaging someone drinks lot tea bags one package package arrived really quickly problems whatsoever
# 실제 요약문 : english tea no
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 예측 요약문 :  great
#
#
# 원문 :  originally received tea holiday gift basket tea drinker life rather like far best tea ever cannot find locally lucky enough find line unique flavor cannot find typical lipton red rose tea
# 실제 요약문 : great tea
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 예측 요약문 :  great
#
#
# 원문 :  like tea tea think like much love basically caffeine free weekends indulge first tasted collection several teas gave xmas went looking amazon glad found
# 실제 요약문 : tea
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 예측 요약문 :  great

# %% [markdown]
# 문장 임베딩 기반 텍스트 랭크

# %%
import numpy as np
import gensim
from urllib.request import urlretrieve, urlopen
import gzip
import zipfile

# %%
urlretrieve("http://nlp.stanford.edu/data/glove.6B.zip", filename="glove.6B.zip")
zf = zipfile.ZipFile('glove.6B.zip')
zf.extractall()
zf.close()

# %%
glove_dict = dict()
f = open('glove.6B.100d.txt', encoding="utf8") # 100차원의 GloVe 벡터를 사용

for line in f:
    word_vector = line.split()
    word = word_vector[0]
    word_vector_arr = np.asarray(word_vector[1:], dtype='float32') # 100개의 값을 가지는 array로 변환
    glove_dict[word] = word_vector_arr
f.close()

# %%
glove_dict['cat']
# Out:
# array([ 0.23088  ,  0.28283  ,  0.6318   , -0.59411  , -0.58599  ,
#         0.63255  ,  0.24402  , -0.14108  ,  0.060815 , -0.7898   ,
#        -0.29102  ,  0.14287  ,  0.72274  ,  0.20428  ,  0.1407   ,
#         0.98757  ,  0.52533  ,  0.097456 ,  0.8822   ,  0.51221  ,
#         0.40204  ,  0.21169  , -0.013109 , -0.71616  ,  0.55387  ,
#         1.1452   , -0.88044  , -0.50216  , -0.22814  ,  0.023885 ,
#         0.1072   ,  0.083739 ,  0.55015  ,  0.58479  ,  0.75816  ,
#         0.45706  , -0.28001  ,  0.25225  ,  0.68965  , -0.60972  ,
#         0.19578  ,  0.044209 , -0.31136  , -0.68826  , -0.22721  ,
#         0.46185  , -0.77162  ,  0.10208  ,  0.55636  ,  0.067417 ,
#        -0.57207  ,  0.23735  ,  0.4717   ,  0.82765  , -0.29263  ,
#        -1.3422   , -0.099277 ,  0.28139  ,  0.41604  ,  0.10583  ,
#         0.62203  ,  0.89496  , -0.23446  ,  0.51349  ,  0.99379  ,
#         1.1846   , -0.16364  ,  0.20653  ,  0.73854  ,  0.24059  ,
#        -0.96473  ,  0.13481  , -0.0072484,  0.33016  , -0.12365  ,
#         0.27191  , -0.40951  ,  0.021909 , -0.6069   ,  0.40755  ,
#         0.19566  , -0.41802  ,  0.18636  , -0.032652 , -0.78571  ,
#        -0.13847  ,  0.044007 , -0.084423 ,  0.04911  ,  0.24104  ,
#         0.45273  , -0.18682  ,  0.46182  ,  0.089068 , -0.18185  ,
#        -0.01523  , -0.7368   , -0.14532  ,  0.15104  , -0.71493  ],
#       dtype=float32)

# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.23.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199770 sha256=70583c254102806a60dea3852eeecd14a70bb0028bb29a694c046df8cd574d41
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.11.1

# %%
# 300차원의 FastText 벡터 사용
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')
ft = fasttext.load_model('cc.en.300.bin')
# Out:
# Downloading https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
